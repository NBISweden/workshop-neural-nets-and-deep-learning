# %% [markdown]
# # Introduction to
# # NBIS Neural Nets & Deep Learning workshop

# %% [markdown]
# ### Who we are
#
#
# Claudio             |Bengt               |Christophe          |Dan                 |Per
# :--------------------:|:--------------------:|:--------------------:|:--------------------:|:--------------------:
# <img src="assets/claudio-mirabello.jpg" alt="Drawing" style="width: 240px;"/>  |  <img src="assets/bengt-sennblad.jpg" alt="Drawing" style="width: 200px;"/>  |  <img src="assets/christophe-avenel.jpg" alt="Drawing" style="width: 200px;"/> |  <img src="assets/dan-rosen.jpg" alt="Drawing" style="width: 200px;"/> | <img src="assets/per-unneberg.jpg" alt="Drawing" style="max-width: 200px; max-height=600px;"/>
#
#
# Marcin              |Nikolay             |Carl                |Olga                |Eva
# :--------------------:|:--------------------:|:--------------------:|:--------------------:|:--------------------:
# <img src="assets/marcin-kierczak.png" alt="Drawing" style="width: 200px;"/>  |  <img src="assets/nikolay-oskolkov.jpg" alt="Drawing" style="width: 200px;"/>  | <img src="assets/carl-nettelblad.jpg" alt="Drawing" style="width: 200px;"/> | <img src="assets/olga-dethlefsen.jpg" alt="Drawing" style="width: 200px;"/>| <img src="" alt="Photo" style="max-width: 200px;max-height=600px;"/>

# %% [markdown]
# # Who you are?

# %% [markdown]
# ## You're our Guinea pigs!

# %% [markdown]
# <img src="./assets/guineapig.jpg" alt="guinea Pigs" width="1200"/>
#
# <font size="1"> (taken from https://www.marinij.com/2018/03/05/guinea-pigs-have-lots-of-love-and-fun-to-share/)</font>

# %% [markdown]
# #### Online classroom
# <font size="5"> [https://nbisweden.github.io/workshop-neural-nets-and-deep-learning/](https://nbisweden.github.io/workshop-neural-nets-and-deep-learning/classroom)</font>
# - Course website:
# <font size="5"> [https://nbisweden.github.io/workshop-neural-nets-and-deep-learning/](https://nbisweden.github.io/workshop-neural-nets-and-deep-learning/)</font>
#     - schedule with links to lectures and exercises
# - The Zoom Main room for:
# <font size="5"> [https://uu-se.zoom.us/j/63739918797](https://uu-se.zoom.us/j/63739918797)</font>
#     - lectures
#     - questions during exercises
# - Zoom breakout rooms will be used for discussions in smaller groups
# - Student slack channel:
# <font size="5"> https://nbisweden.slack.com/app_redirect?channel=nn_dl_students </font>
#     - questions during lectures or exercises
# - HackMD:
# <font size="5"> [https://hackmd.io/fZc9DFyDSOO5Kd4RORb4Uw](https://hackmd.io/fZc9DFyDSOO5Kd4RORb4Uw) </font>
#     - working area for exercises, etc.

# %% [markdown]
# #### Practical issues
# - Try to keep your **cameras on**, but **microphone muted**
# - Lectures with many breaks
# - Take lots of small breaks also when working with the exercises
# - We will try to stick to the schedule, but it's only preliminary until it's happened
# - If you have any questions during the lecture, feel free to unmute and ask. If you don't want to ask in the Zoom meeting, write the question in the chat or on slack

# %% [markdown]
# ### Schedule
# Can be found on the Course website [here](https://nbisweden.github.io/workshop-neural-nets-and-deep-learning/schedule)

# %% [markdown]
# ### Learning outcomes
# can be found on the Course website [here](https://nbisweden.github.io/workshop-neural-nets-and-deep-learning/learningOutcomes)

# %% [markdown]
# ### Prerequisites
# can be found on the Course website [here](https://nbisweden.github.io/workshop-neural-nets-and-deep-learning/prerequisites)

# %% [markdown]
# #### [HackMD](https://hackmd.io/fZc9DFyDSOO5Kd4RORb4Uw)
# - Write a short presentation of yourself under *Autobiographies*

# %% [markdown]
# ### So, this course is about Artificial Neural networks (Anns)

# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join('..', 'common_assets')))
import numpy as np
import matplotlib.pyplot as plt
from draw_neural_net import draw_neural_net

layer_sizes = [ 4, 3, 2, 3, 4 ]
weights = [
    np.array(
        [
            [ "w_{1,1}", "w_{1,2}", "w_{1,3}"],
            [ "w_{2,1}", "w_{2,2}", "w_{2,3}"],
            [ "w_{3,1}", "w_{3,2}", "w_{3,3}"],
            [ "w_{4,1}", "w_{4,2}", "w_{4,3}"]
        ]
    ),

    np.array(
        [
            [ "w_{1,1}", "w_{1,2}"],
            [ "w_{2,1}", "w_{2,2}"],
            [ "w_{3,1}", "w_{3,2}"]

        ]
    ),

 #   np.array(
 #       [
 #           [ "w_{1,1}", "w_{1,2}"],
 #           [ "w_{2,1}", "w_{2,2}"],
 #       ]
 #  ),
        np.array(
        [
            [ "w_{1,1}", "w_{1,2}", "w_{1,3}"],
            [ "w_{2,1}", "w_{2,2}", "w_{2,3}"]
        ]
    ),
        np.array(
        [
            [ "w_{1,1}", "w_{1,2}", "w_{1,3}","w_{1,4}"],
            [ "w_{2,1}", "w_{2,2}", "w_{2,3}","w_{2,4}"],
            [ "w_{3,1}", "w_{3,2}", "w_{3,3}","w_{3,4}"]
        ]
    )
]
biases = [
    np.array(
        ["b_1", "b_2","b_3"]
    ), 
    np.array(
        ["b_1", "b_2"]
    ), 
    np.array(
        ["b_1", "b_2", "b_3"]
    ), 
    np.array(
        ["b_1", "b_2", "b_3", "b_4"]
    ), 


]

figAE = plt.figure(figsize=(12,12))

ax = figAE.gca()
ax.axis('off')

draw_neural_net(ax, layerSizes=layer_sizes) #, weights= weights, biases=biases)

# %% [markdown]
# ### .... What is that?

# %% [markdown]
# # AI vs ML vs ANN vs DL

# %% [markdown]
# <img src="./assets/vennAiMlAnnDl2.jpg" alt="ai_ml_ann_dl" width="1600"/>
#
# <font size="1"> (taken from https://medium.com/ai-in-plain-english/artificial-intelligence-vs-machine-learning-vs-deep-learning-whats-the-difference-dccce18efe7f)</font>

# %% [markdown]
# #### AI  -- Artificial Intelligence
# - The science and engineering  of creating intelligent machines
#     - or machines that behave as they were intelligent

# %% [markdown]
# #### ML -- Machine learning
# - Subset of AI
# - Computer algorithms that learn/improve from experience

# %% [markdown]
# #### ANN -- Artificial Neural Networks
# - Subset of ML
# - Model of human neural networks
# - Networks built up by artificial neurons

# %%
import matplotlib.pyplot as plt
from matplotlib import lines as lines
# Create figure
fig = plt.figure(figsize = (7, 7)) 
# Add subplot to figure
ax = fig.add_subplot()
plt.axis('off')
# Show empty plot
plt.show()

# %% [markdown]
# #### DL -- Deep Learning
# - Subset of ANN (? -- depend on definition of ANN)
# - ANN with more than one hidden layer

# %% [markdown]
# # So where does statistics fit in?

# %% [markdown]
# ### Statistics and ML -- parallel and overlapping?

# %% [markdown]
# ###### Share
# - methodological elements/framework
# - are both data-dependent
# - both have "*models*"
#     - Stat:  explicit probabilistic model
#     - ML: implicit "*graphical*" model
#         - (samples from array of models)
# - problems
#      - over-fitting
#      - over-parameterization

# %% [markdown]
# ###### Typically differ in
# - optimization
#     - Stat: analytically under the probabilistic model
#     - ML: *learns* from training data, evaluates on test data
# - *main* aims
#     - Stat: infer relationships between variables
#     - ML: predictions about unseen data
# - size of data
#     - stat: small vs ML: big data
#          - variables and samples

# %% [markdown]
# # ... and what about Data Science?

# %% [markdown]
# <img src="./assets/vennAiMlDlDs.png" alt="Neuron" width="1200"/>
#
# <font size="1"> (taken from https://www.javatpoint.com/data-science-vs-machine-learning)</font>

# %% [markdown]
# <img src="./assets/vennDs2.png" alt="Neuron" width="1200"/>
#
# <font size="1"> (taken from https://crate.io/a/machine-learning-cratedb-jupyter/)</font>

# %% [markdown]
# #### ... ~Don't know~ I mean, outside the scope of this study

# %% [markdown]
# # Where does ANN come from?

# %% [markdown]
# # History

# %% [markdown]
# ### First wave of ANN (funding)
# - 1943 First model of biological neruon (McCulloch & Pitts)
# - 1949 Hebbian Learning rules for ANN, (Donald Hebb)
# - 1951 First ANN (Minsky)
# - 1958 The *Perceptron* -- linear classification
# - 1969 Limitations of the perceptron (Minsky & Papert)

# %% [markdown]
# <img src="./assets/perceptron.gif" alt="Neuron" width="1200"/>
#
# <font size="1"> (taken from https://www.sciencedirect.com/topics/neuroscience/perceptron)</font>

# %% [markdown]
# <img src="./assets/rosenblatt.jpg" alt="Neuron" width="1200"/>
#
# <font size="1"> (taken from https://news.cornell.edu/stories/2019/09/professors-perceptron-paved-way-ai-60-years-too-soon)</font>

# %% [markdown]
# # History

# %% [markdown]
# ### Second wave of ANN (funding)
# - (1975 Back propagation algorithm (Werbos))
# - 1986 Back propagation rediscovered and sigmoid activation -- ANNs in vogue again
# - 1985-87 ANN conferences, societies started (IEEE, INNS)
# - Vanishing gradient problem
# - SVM outcompetes ANNs, ANNs survives in protein structure prediciton (e.g., CASP)

# %% [markdown]
# <img src="./assets/backprop.png" alt="Neuron" width="1200"/>
#
# <font size="1"> (taken from https://www.kdnuggets.com/2019/01/backpropagation-algorithm-demystified.html)</font>

# %% [markdown]
# <img src="./assets/casp.png" alt="Neuron" width="1200"/>
#
# <font size="1"> (taken from https://predictioncenter.org)</font>

# %% [markdown]
# # History

# %% [markdown]
# ### Third wave of ANN (funding)
# - GPUs and parallelization
# - "Deep Learning" buzzword and performing well in contests
# - 1997 Recursive Neural Nets. LSTMs (Smidhuber & Hochreiter)
# - 2000 ReLU (Hahnloser et al.?)
# - 2011 CNNs
# - ANNs are everywhere

# %% [markdown]
# <img src="./assets/rnn.png" alt="Neuron" width="1200"/>

# %% [markdown]
# <img src="./assets/cnn.jpg" alt="Neuron" width="1200"/>
#
# <font size="1"> (taken from https://towardsdatascience.com/a-comprehensive-guide-to-convolutional-neural-networks-the-eli5-way-3bd2b1164a53)</font>

# %% [markdown]
# # Applications

# %% [markdown]
# <img src="./assets/alphafold.gif" alt="Neuron" width="1200"/>
#
# <font size="1"> (taken from https://www.theverge.com/2020/12/1/21754310/deepmind-alphafold-ai-protein-folding-casp-competition)</font>

# %% [markdown]
# <img src="./assets/mnist.png" alt="mnist" width="1200"/>
#
# <font size="1"> (taken from https://machinelearningmastery.com/handwritten-digit-recognition-using-convolutional-neural-networks-python-keras/)</font>

# %% [markdown]
# <img src="./assets/selfdriving.jpg" alt="mnist" width="1200"/>
#
# <font size="1"> (taken from https://spectrum.ieee.org/computing/embedded-systems/bringing-big-neural-networks-to-selfdriving-cars-smartphones-and-drones)</font>

# %% [markdown]
# <img src="./assets/gan_faces.jpg" alt="mnist" width="1200"/>
#
# <font size="1"> (taken from https://medium.com/syncedreview/gan-2-0-nvidias-hyperrealistic-face-generator-e3439d33ebaf)</font>

# %% [markdown]
# # Time for a break

# %% [markdown]
# - **pattern recognition**
# - non-linear classification/regression?
#     - signature verification
#     - cybersecurity
# - image/character recognition
#     - handwriting (mnist)
#     - bioimages
#     - faces
#     - 3D object recognition
# - forecasting/prediction
#     - business
#     - medical diagnosis
#     - generate images (faces)

# %% [markdown]
# - dimensional reduction
#     - bar-coding
# - sequence recognition
#     - speech
#     - text
#     - NLP
# - data mining
# - time series
# - protein structure prediciton
