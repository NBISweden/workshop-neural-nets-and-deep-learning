# %% [markdown]
# # ANN Building Blocks

# %% [markdown]
# # Biological Neurons

# %% [markdown]
# <img src="./assets/neuron2.png" alt="Neuron" width="800"/>

# %% [markdown]
# ## Algorithm
#
# - *Multiple input (on/off):*
#     - from 1-several neurons
#
# - *Processing*:
#      - _Combination_: of inputs
#      - _Activation_: on or off state
#
# - *Single output (on/off):* to 1-several neurons

# %% [markdown]
# # Artificial neurons

# %% [markdown]
# ### Algorithm
#
# - *Multiple input:*
#     - from 1-several neurons
#
# - *Processing*:
#      - _Combination_: of inputs  -- **linear model**
#      - _Activation_: **activation function**
#
# - *Single output:* to 1-several neurons
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join('..', 'common_assets')))
import numpy as np
import matplotlib.pyplot as plt
from draw_neural_net import draw_neural_net

layer_sizes = [3,1,1]

weights = [
    np.array(
        [
            ["w_{1,1}"],
            ["w_{2,1}"], 
            ["w_{3,1}"],
        ]
    ),
    np.array(
        [
            [""]
        ]
    )

]
biases = [
    np.array(
        ["b1"]
    ), 
    np.array(
        ["b_2"]
    )
]
figNeuron = plt.figure(figsize=(8, 8))
ax = figNeuron.gca()
ax.axis('off')

draw_neural_net(ax,
                layerSizes=layer_sizes, 
                weights=weights, 
                biases=biases, 
                hiddenLayerPrefix = "", 
                outLayerPrefix = "", 
                inLayerPrefix ="", 
                biasNodePrefix = "b",
                inputPrefix = "a'", 
                outputPrefix = "a", 
                otherNodePrefix =  r"z_{m}",
                hideInOutPutNodes=True,
                nodeFontSize = 25,
                edgeFontSize = 20, 
                edgeWidth = 3
               )

# %% [markdown]
# # Artificial neurons

# %% [markdown]
# ### Algorithm
#
# - *Multiple input:*
#     - from 1-several neurons
#
# - *Processing*:
#      - _Combination_: of inputs  -- **linear model**
#      - _Activation_: **activation function**
#
# - *Single output:* to 1-several neurons
#
# #### Weighted linear combination of input:
# $\begin{eqnarray*}
# z_j &=& \sum_{i} w_{i,j} a_{i} + b_j\\
# \textrm{weights}&& w_{i,j}\\
# \textrm{bias}&& b_j
# \end{eqnarray*}$
#
# <br>
# <br>

# %%
figNeuron

# %% [markdown]
# # Artificial neurons

# %% [markdown]
# ### Algorithm
#
# - *Multiple input:*
#     - from 1-several neurons
#
# - *Processing*:
#      - _Combination_: of inputs  -- **linear model**
#      - _Activation_: **activation function**
#
# - *Single output:* to 1-several neurons
#
# #### Weighted linear combination of input:
# $\begin{eqnarray*}
# z_j &=& \sum_{i} w_{i,j} a_{i} + b_j\\
# \textrm{weights}&& w_{i,j}\\
# \textrm{bias}&& b_j
# \end{eqnarray*}$
#
# #### Sigmoid (logistic) activation function:
# $a_j = \sigma(z_j)$

# %%
figNeuron

# %% [markdown]
# # The Sigmoid Neuron

# %% [markdown]
# #### Weighted linear combination of input:
#
# - $z_j = \sum_{i} w_{i,j} a'_{i} + b_j$
#
# #### Sigmoid/logistic activation function
#
# - $a_j=\sigma(z_j) = \frac{1}{1+e^{-z_j}}$
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %%
import numpy as np
import matplotlib.pyplot as plt
def sigma(x):
    return 1/(1+np.exp(-x))

# Creating vectors x and  
z = np.linspace(-10, 10, 100) 
a = [ sigma(x) for x in z ]
  
log = plt.figure(figsize = (6, 6)) 
# Create the plot 
plt.plot(z, a)
plt.title("Logistic function")
plt.xlabel('z') 
plt.ylabel('$\sigma(z)$') 
# Show the plot 
plt.show()

# %% [markdown]
# # The Sigmoid Neuron

# %% [markdown]
# #### Weighted linear combination of input:
#
# - $z_j = \sum_{i} w_{i,j} a'_{i} + b_j$
#
# #### Sigmoid/logistic activation function
#
# - $a_j=\sigma(z_j) = \frac{1}{1+e^{-z_j}}$
#
# <br>
#
# #### Compare with logistic GLM
#
# - Weighted linear combination of input:
#     - $z = \sum_{i} \beta_{i} x_{i} + \alpha$
# - Sigmoid/logistic link function
#     - $Pr[y=1|x] = p = \sigma(z) = \frac{1}{1+e^{-z}}$
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %%
log

# %% [markdown]
# # The Sigmoid Neuron

# %% [markdown]
# #### Weighted linear combination of input:
#
# - $z_j = \sum_{i} w_{i,j} a'_{i} + b_j$
#
# #### Sigmoid/logistic activation function
#
# - $a_j=\sigma(z_j) = \frac{1}{1+e^{-z_j}}$
#
# <br>
#
# #### Compare with logistic GLM
#
# - Weighted linear combination of input:
#     - $z = \sum_{i} \beta_{i} x_{i} + \alpha$
# - Sigmoid/logistic link function
#     - $Pr[y=1|x] = p = \sigma(z) = \frac{1}{1+e^{-z}}$
#
# **... or equivalently**
#
# $\begin{eqnarray}
#  \sigma^{-1}(p)&=&\log\left(\frac{p}{1-p}\right) =\\
# logit(p) &=& \sum_{i}\beta_{i} x_{i} + \alpha
# \end{eqnarray}$

# %%
log

# %% [markdown]
# # Example

# %% [markdown]
# Let inputs be:
# $\begin{eqnarray}
# a'_1&=&1\\
# a'_2&=&0\\
# a'_3&=&1
# \end{eqnarray}$
#
# and we have
# $\begin{eqnarray}
# z_1 &=& \sum_i w_{i,1}a'_i + b_1\\
# a_1 &=& \sigma(z_1)
# \end{eqnarray}$

# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join('..', 'common_assets')))
import numpy as np
import matplotlib.pyplot as plt
from draw_neural_net import draw_neural_net

layer_sizes = [3,1,1]

weights = [
    np.array(
        [
            ["0.3"],
            ["0.8"], 
            ["0.2"],
        ]
    ),
    np.array(
        [
            [""]
        ]
    )

]
biases = [
    np.array(
        ["-0.5"]
    ), 
    np.array(
        ["b_2"]
    )
]

figNeuron1 = plt.figure(figsize=(8, 8))
ax = figNeuron1.gca()
ax.axis('off')

draw_neural_net(ax,
                layerSizes=layer_sizes, 
                weights=weights, 
                biases=biases, 
                hiddenLayerPrefix = "", 
                outLayerPrefix = "", 
                inLayerPrefix ="", 
                biasNodePrefix = "b",
                inputPrefix = "a'", 
                outputPrefix = "a", 
                otherNodePrefix =  r"z_{m}",
                hideInOutPutNodes=True,
                nodeFontSize = 25,
                edgeFontSize = 20, 
                edgeWidth = 3
               )

# %% [markdown]
# $z_1 = 0.3 \times 1 + 0.8 \times 0 + 0.2 \times 1 - 0.5 = ? $

# %% [markdown]
# $a_1 = \sigma(z_1) =  ?$

# %% [markdown]
# # Example

# %% [markdown]
# Let inputs be:
# $\begin{eqnarray}
# a'_1&=&1\\
# a'_2&=&0\\
# a'_3&=&1
# \end{eqnarray}$
#
# and we have
# $\begin{eqnarray}
# z_1 &=& \sum_i w_{i,1}a'_i + b_1\\
# a_1 &=& \sigma(z_1)
# \end{eqnarray}$

# %%
figNeuron1

# %% [markdown]
# $z_1 = 0.3 \times 1 + 0.8 \times 0 + 0.2 \times 1 - 0.5 = 0$

# %% [markdown]
# $a_1 = \sigma(z_1) = \frac{1}{1+e^{-0}} = ?$

# %% [markdown]
# # Example

# %% [markdown]
# Let inputs be:
# $\begin{eqnarray}
# a'_1&=&1\\
# a'_2&=&0\\
# a'_3&=&1
# \end{eqnarray}$
#
# and we have
# $\begin{eqnarray}
# z_1 &=& \sum_i w_{i,1}a'_i + b_1\\
# a_1 &=& \sigma(z_1)
# \end{eqnarray}$

# %%
figNeuron1

# %% [markdown]
# $z_1 = 0.3 \times 1 + 0.8 \times 0 + 0.2 \times 1 - 0.5 = 0$

# %% [markdown]
# $a_1 = \sigma(z_1) = \frac{1}{1+e^{-0}} = 0.5$

# %% [markdown]
# #### So, if a sigmoid artificial neuron is just another way of doing logistic regression?

# %% [markdown]
# #### ... then what's all the fuss about?

# %% [markdown]
# #### The *fuss* happens when you connect several neurons into a network

# %%
layer_sizes= (2,3,4,4,4,4,4,3,1)

fig = plt.figure(figsize=(10, 10))
ax = fig.gca()
ax.axis('off')

draw_neural_net(ax, 
                layerSizes=layer_sizes, 
                otherNodePrefix = "",
                inNodePrefix = "",
                hideBias = True)

# %% [markdown]
# ## Feed-forward artifical neural networks (ffANN)

# %% [markdown]
# ### Layers
# - "Columns" of 1-many neurons
#
# - A single *Input layer*
#     - Input neurons  receives *data input* and passes it to next layer
# - 1-many *Hidden layer(s)*
#     - Articial neurons process their input and deliver output to next layer
# - A single *Output layer*
#     - Artifical neurons process their input and deliver final output $\hat{y}$
#         + output $\hat{y}_j = a_j$
#         + Continuous $\hat{y}$: **Regression**
#         + Discrete $\hat{y}$: **Classification**

# %%
layer_sizes = [1, 3, 1]
weights = [
    np.array(
        [
            [ "w_{1,1}", "w_{1,2}", "w_{1,3}"]
        ]
    ),
        np.array(
        [
            [ "w_{1,1}" ],
            [ "w_{2,1}" ],
            [ "w_{3,1}" ]
        ]
    )


]
biases = [
    np.array(
        ["b_1", "b_2", "b_3"]
    ), 
    np.array(
        [ "b_1"]
    ),    
]

fig = plt.figure(figsize=(8, 8))

ax = fig.gca()
ax.axis('off')

draw_neural_net(ax, 
                layerSizes=layer_sizes,
                weights= weights, 
                biases=biases)

# %% [markdown]
# ### Connectivity between layers
# - ffANN are fully connected
#    - each neuron in a layer is connected to each neurons in next layer

# %% [markdown]
# ## ffANN examples

# %%
layer_sizes = [1, 3, 1]
weights = [
    np.array(
        [
            [ "w_{1,1}", "w_{1,2}", "w_{1,3}"]
        ]
    ),
        np.array(
        [
            [ "w_{1,1}" ],
            [ "w_{2,1}" ],
            [ "w_{3,1}" ]
        ]
    )


]
biases = [
    np.array(
        ["b_1", "b_2", "b_3"]
    ), 
    np.array(
        [ "b_1"]
    ),    
]

fig = plt.figure(figsize=(5, 5))

ax = fig.gca()
ax.axis('off')

draw_neural_net(ax, 
                layerSizes=layer_sizes,
                nodeFontSize = 10,
                edgeFontSize = 8, 
                weights= weights, 
                biases=biases)

# %% [markdown]
# <font size="6"> Other drawing style, omitting $w$ and $b$. </font>
# <img src="./assets/fig1.png" alt="ANN1" width="600"/>

# %% [markdown]
# ## ffANN examples

# %%
layer_sizes = [3, 3, 3, 1]
weights = [
    np.array(
        [
            [ "w_{1.1}",  "w_{2.1}",  "w_{3.1}" ],
            [ "w_{1.2}",  "w_{2,2}",  "w_{3.1}" ],
            [ "w_{1.2}",  "w_{2,2}",  "w_{3.1}" ]
        ]
    ),
    np.array(
        [
            [ "w_{1.1}",  "w_{2.1}",  "w_{3.1}" ],
            [ "w_{1.2}",  "w_{2,2}",  "w_{3.1}" ],
            [ "w_{1.2}",  "w_{2,2}",  "w_{3.1}" ]
        ]
    ),
    np.array(
        [
            [ "w_{1.1}" ],
            [ "w_{2.1}" ],
            [ "w_{3.1}" ]
        ]
    )
]
biases = [
    np.array(
        [ "b_1", "b_2", "b_3" ]
    ), 
    np.array(
        [ "b_1" , "b_2", "b_3" ]
    ),
    np.array(
        [ "b_1" ]
    )
    
]

fig = plt.figure(figsize=(5, 5))

ax = fig.gca()
ax.axis('off')

draw_neural_net(ax, 
                layerSizes=layer_sizes, 
                nodeFontSize = 10,
                edgeFontSize = 8, 
                weights= weights, 
                biases=biases)

# %% [markdown]
# <font size="6"> Often layers are 'boxed' </font>
# <img src="./assets/fig2.png" alt="ANN2" width="600"/>

# %% [markdown]
# ## ffANN examples

# %% [markdown]
# <font size="6"> layers w >1 dimension (e.g., images) --  (messy!)</font>
# <img src="./assets/fig3.png" alt="Neuron" width="800"/>

# %% [markdown]
# <font size="6"> Simplify! nodes and arrows implicit</font><img src="./assets/fig3b.png" alt="Neuron" width="800"/>

# %% [markdown]
# <font size="6"> Collect similar layers into 'blocks' </font><img src="./assets/fig3c.png" alt="Neuron" width="800"/>

# %% [markdown]
# ## ffANN examples

# %% [markdown]
# <font size="6"> Also other type of layers/blocks (cf. coming lectures) </font><img src="./assets/vgg16.png" alt="Neuron" width="1200"/>

# %% [markdown]
# # Hidden Layers
#
# ### Inutitive function of hidden layers?
# - Each layer can be viewed as transforming the original data to a new multi-dimensional space.
# - *A hidden layer should, in practice, have at least two neurons to be meaningful*
#     - Single neuron layer collapses information and forms a bottleneck
#     - A bottleneck early heavily constrains the NN

# %% [markdown]
# ### Depth
# - number of hidden layers + output layers

# %% [markdown]
# ###  Deep Learning
# - Formally, ANNs with depth > 1
#     - (often include more advanced layers as well)

# %% [markdown]
# ## Why deep Learning?

# %% [markdown]
# ## For Regression
# - Single layer $\approx$ logistic regression
#
# <br>
# <br>

# %%
import random

def sigma(x):
    return 1/(1+np.exp(-x))

# Creating vectors x and  
z = np.linspace(-10, 10, 100) 
w = [ sigma(x) for x in z ]
  
x = [ random.gauss(m, 0.1) for m in np.linspace(-10, 10, 100) ]
y = [ random.gauss(sigma(x), 0.1) for x in z ]
    
fig = plt.figure(figsize = (5, 5)) 
# Create the plot 
plt.plot(z, w)
plt.scatter(x,y, c="red")
plt.title("Logistic function")
plt.xlabel('z') 
plt.ylabel('$\sigma(z)$') 
# Show the plot 
plt.show()

# %%
from matplotlib import lines as lines
# Create figure
fig = plt.figure(figsize = (7, 7)) 
# Add subplot to figure
ax = fig.add_subplot()
plt.axis('off')
# Show empty plot
plt.show()

# %%
import random

def sigma(x):
    return 1/(1+np.exp(-x))

# Creating vectors x and  
z = np.linspace(-10, 10, 100) 
w = [ sigma(x) for x in z ]
  
x = [ random.gauss(m, 0.1) for m in np.linspace(-10, 10, 100) ]
y = [ random.gauss(sigma(x), 0.1) for x in z ]
    
fig = plt.figure(figsize = (6, 6)) 
# Create the plot 
plt.plot(z, w)
plt.scatter(x,y, c="red")
plt.title("Logistic function")
plt.xlabel('z') 
plt.ylabel('$\sigma(z)$') 
# Show the plot 
plt.show()

# %%
from matplotlib import lines as lines
# Create figure
fig = plt.figure(figsize = (7, 7)) 
# Add subplot to figure
ax = fig.add_subplot()
plt.axis('off')
# Show empty plot
plt.show()

# %% [markdown]
# ## Why deep Learning?

# %% [markdown]
# ## For Regression
# - Single layer $\approx$ logistic regression
# - More layers $\rightarrow$
#     - more complex, non-linear, models

# %%
import matplotlib.cm as cm 
import random

n = 256
angle = np.linspace(0, 0.95 * 2 * np.pi, n)
radius = np.linspace(.5, 1., n)

#angle = np.linspace(0, 12 * 2 * np.pi, n)
#radius = np.linspace(.5, 1., n)


x = [ random.gauss(m, 0.1) for m in radius * np.cos(angle) ]
y = [ random.gauss(m, 0.1) for m in radius * np.sin(angle) ]

z = radius * np.cos(angle)
w = radius * np.sin(angle)

figSpiral = plt.figure(figsize = (5, 5)) 
plt.scatter(x,y,c = "red", cmap = cm.hsv)
plt.plot(z,w)
plt.show()

# %%
from matplotlib import lines as lines
# Create figure
fig = plt.figure(figsize = (5, 5)) 
# Add subplot to figure
ax = fig.add_subplot()
plt.axis('off')
# Show empty plot
plt.show()

# %% [markdown]
# ## Why deep Learning?

# %% [markdown]
# ## For Regression
# - Single layer $\approx$ logistic regression
# - More layers $\rightarrow$
#     - more complex, non-linear, models

# %%
figSpiral

# %% [markdown]
# ## For classification

# %%
import random

# Creating vectors x and  
a1 = 5
b1= -0.75
a2=8
b2 = -0.4
n=50
z = np.linspace(0, 10, n) 
w1 = [ a1 + b1 * zi for zi in z ] 
w2 = [ a2 + b2 * zi for zi in z ] 

x = [ random.random() *10 for k in list(range(n)) ]
y = [ random.random() *10 for k in list(range(n)) ]
col = [ "red" if y[k] > a1 + b1 * x[k] and y[k] < a2 + b2 * x[k] else "blue" 
       for k in list(range(n)) ]

fig = plt.figure(figsize = (5, 5)) 
# Create the plot 
plt.scatter(x, y, c=col)
plt.xlabel('x') 
plt.ylabel('y') 
plt.xlim((0,10))
plt.ylim((0,10))
# Show the plot 
plt.show()

# %% [markdown]
# ## Why deep Learning?

# %% [markdown]
# ## For Regression
# - Single layer $\approx$ logistic regression
# - More layers $\rightarrow$
#     - more complex, non-linear, models

# %%
figSpiral

# %% [markdown]
# ## For classification
# - Single layer $\approx$ one hyper-plane

# %%
import random

fig = plt.figure(figsize = (5, 5)) 
# Create the plot 
plt.scatter(x, y, c=col)
plt.plot(z, w2)
plt.xlabel('x') 
plt.ylabel('y') 
plt.xlim((0,10))
plt.ylim((0,10))
# Show the plot 
plt.show()

# %% [markdown]
# ## Why deep Learning?

# %% [markdown]
# ## For Regression
# - Single layer $\approx$ logistic regression
# - More layers $\rightarrow$
#     - more complex, non-linear, models

# %%
figSpiral

# %% [markdown]
# ## For classification
# - Single layer $\approx$ one hyper-plane
# - Adding layers $\rightarrow$
#     - more hyper planes $\rightarrow$
#     - more advanced classification

# %%
fig = plt.figure(figsize = (5, 5)) 

# Create the plot
plt.scatter(x, y, c=col)
plt.plot(z, w1)
plt.plot(z, w2)
plt.xlabel('x') 
plt.ylabel('y') 
plt.xlim((0,10))
plt.ylim((0,10))
# Show the plot 
plt.show()

# %% [markdown]
# # Mini exercise
#   - [http://playground.tensorflow.org/](http://playground.tensorflow.org/)
#       + Try different input "problems"
#       + Investigate how different depth affect classification
#       + Run for several epochs (=iterations)
