# %%
# %matplotlib inline

import matplotlib.pyplot as plt

def plot_loss_acc(history):
    plt.plot(history.history['sparse_categorical_accuracy'])
    plt.plot(history.history['val_sparse_categorical_accuracy'])
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train acc', 'val acc', 'train loss', 'val loss'], loc='upper left')
    plt.show()

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import keras
import h5py
import sys
from keras import Model
from keras.layers import Input, Embedding, Flatten, Dense, Dropout, LSTM, Conv1D
from keras.layers.wrappers import Bidirectional
from keras.utils.io_utils import HDF5Matrix
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
from scipy.spatial.distance import squareform
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)
np.set_printoptions(threshold=sys.maxsize)

# %%
#Test proteins have distances = 1.0 everywhere
#unique_protein_idx = np.where(np.sum(distance_matrix,axis=1) == 27031)[0]
#print(' '.join(distance_matrix.columns.values[unique_protein_idx]))
#sorted_similarity_indexes = np.sum(distance_matrix,axis=1).sort_values()

#get more common proteins like so:
#train_set = set()
#i = 0
#for protein_index, value in sorted_similarity_indexes.items():
#    similar_indexes = np.where(distance_matrix.iloc[protein_index,:] != 1.0)[0]
#    [train_set.add(element) for element in list(similar_indexes)]
#    
#    i+=1
#    if i > 1000:
#        #print(len(train_set))
#        break
#print(' '.join(distance_matrix.columns.values[list(train_set)]))

# %%
input_dataset = 'data/dataset_sseq_singleseq.hdf5'
target_list_path = 'data/train_set'
test_list_path = 'data/test_set'

# This switches between a convolutional or a recurrent architecture 
convolutional = False

nb_epoch = 10
batch = 32
window = 31
dropfrac = 0.5
embed_size = 16
bidir_size = 64

#INPUTS timesteps are columns from the MSA
inputs = Input(shape=(window,))
embed = Embedding(21, embed_size, input_length=window, batch_input_shape=(batch, window))(inputs)

bidir = Bidirectional(LSTM(bidir_size, return_sequences=True), merge_mode='ave')(embed)
bidir2 = Bidirectional(LSTM(32, return_sequences=False))(bidir)

conv = Conv1D(32, 9, activation='relu')(embed)
conv2 = Conv1D(64, 5, activation='relu')(conv)
conv3 = Conv1D(128, 3, activation='relu')(conv2)

if convolutional:
    dense = Dense(32)(Flatten()(conv2))
else:
    dense = Dense(32)(bidir2)

dense2 = Dense(16)(dense)
outputs = Dense(3, activation='softmax')(dense2)

#MODEL
model_sseq = tf.keras.Model(inputs, outputs)

print('Compiling the model...')
model_sseq.compile(optimizer='rmsprop',
              loss='sparse_categorical_crossentropy',
              metrics=['sparse_categorical_accuracy'])
model_sseq.summary()
# Out:
# Compiling the model...
# Model: "functional_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 31)]              0
# _________________________________________________________________
# embedding_4 (Embedding)      (None, 31, 16)            336
# _________________________________________________________________
# bidirectional_8 (Bidirection (None, 31, 32)            12544
# _________________________________________________________________
# bidirectional_9 (Bidirection (None, 16)                2624
# _________________________________________________________________
# dense_12 (Dense)             (None, 32)                544
# _________________________________________________________________
# dense_13 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_14 (Dense)             (None, 3)                 51
# =================================================================
# Total params: 16,627
# Trainable params: 16,627
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Look at the architecture above:
# * What does putting the variable "convolutional" to False mean? What happens to the bidirectional layers when we are using a convolutional architecture?
# * Which architecture would be best for this type of dataset in your opinion?

# %%
def count_steps(target_list_data, window=None, batch=None):
    
    n_targets = len(target_list_data)
    
    if window is None:
        return n_targets
    
    target_index = 0
    n_steps = 0
    for target in target_list_data:
        
        try:
            X_batch = np.asarray(HDF5Matrix(input_dataset, 'inputs/' + target))  # length x max_depth
        except:
            continue

        length = X_batch.shape[0]
                                 
        n_steps += int(((length - window + 1) / batch))
    return n_steps
        
def generate_inputs_window(target_list_data, window=None, batch=None, shuffle=False):

    n_targets = len(target_list_data)
    if shuffle:
        random.shuffle(target_list_data)
        
    full_length = False
    if window is None:
        full_length = True
    
    target_index = 0
    
    while 1:
        
        target = target_list_data[target_index]
        target_index += 1
        target_index = target_index % n_targets

        # create numpy arrays of input data
        # and labels, from each line in the file
        try:
            X_batch = np.asarray(HDF5Matrix(input_dataset, 'inputs/' + target))  # length x max_depth
        except:
            continue

        length, max_depth = X_batch.shape[0], X_batch.shape[1]
                                        # 0...00length00...0, max_depth
        if full_length:
            batch = length
            window = length
                    
        if not full_length: #submitting batches of windows
            X_batch = np.lib.pad(X_batch, [(int(window / 2), int(window / 2)), (0, 0)], 'constant', constant_values=(0, 0))
            X_batch_windows = []
            for i in range(length):
                X_batch_windows.append(X_batch[i:i + window, :1].reshape(window))
        else:
            X_batch_windows = X_batch[:, :1]
            
        labels_batch_sseq = np.squeeze(np.asarray(HDF5Matrix(input_dataset, 'labels_sseq/' + target)))
        
       # print(np.array(X_batch_windows).shape)
        
        for i in range(0, length, batch):
            # length x 1 (sparse, 3 class)
            yield (np.array(X_batch_windows)[i:i+batch], labels_batch_sseq[i:i+batch])
    
    target_list_data = target_list_file.readlines()

# %%
def count_steps_31(target_list_data, batch=None):
    
    n_targets = len(target_list_data)
    
    if window is None:
        return n_targets
    
    target_index = 0
    n_steps = 0
    for target in target_list_data:
        
        try:
            X_batch = np.asarray(HDF5Matrix(input_dataset, 'inputs_windows/' + target))  # length x max_depth
        except:
            continue

        length = X_batch.shape[0]
                                 
        n_steps += int(((length - window + 1) / batch))
    return n_steps
        
def generate_inputs_window_31(X, y, target_list_data, batch=None, shuffle=False):

    n_targets = len(target_list_data)
    if shuffle:
        random.shuffle(target_list_data)
    
    target_index = 0
    while 1:
        
        target = target_list_data[target_index]
        target_index += 1
        target_index = target_index % n_targets

        # create numpy arrays of input data
        # and labels, from each line in the file
        try:
            X_batch = X[target]
        except:
            continue

        length = X_batch.shape[0]
                                        # 0...00length00...0, max_depth                    
            
        labels_batch_sseq = y[target]
        
       # print(np.array(X_batch_windows).shape)
        
        for i in range(0, length, batch):
            # length x 1 (sparse, 3 class)
            yield (X_batch[i:i+batch], labels_batch_sseq[i:i+batch])
    

def load_inputs_31(target_list_data, shuffle=False):

    X = {}
    y = {}
    
    n_targets = len(target_list_data)
    if shuffle:
        random.shuffle(target_list_data)
            
    target_index = 0
    
    #X = np.zeros((0,31))
    #y = np.zeros(0)

    for target_index in range(n_targets):

        target = target_list_data[target_index]

        try:
            X_batch = np.asarray(HDF5Matrix(input_dataset, 'inputs_windows/' + target))  # length x max_depth
        except:
            continue

        length = X_batch.shape[0]
                                        # 0...00length00...0, max_depth                    
        
        X[target] = X_batch
        #y = np.concatenate((y,np.squeeze(np.asarray(HDF5Matrix(input_dataset, 'labels_sseq/' + target)))))
        y[target] = np.squeeze(np.asarray(HDF5Matrix(input_dataset, 'labels_sseq/' + target)))
    return X, y

# %% [markdown]
# Let's start by taking the classical approach of randomly splitting the data in a trainset and a validation set (95%/5%), train a network on the trainset and see what the score on the validation changes epoch by epoch:

# %%
import random
target_list_file = open(target_list_path)
target_list = target_list_file.readlines()
random.shuffle(target_list)
n_targets = len(target_list)
train_list = target_list[int(n_targets/20):] #95% train
validation_list = target_list[:int(n_targets/20)] #5% validation

validation_steps = count_steps_31(validation_list, batch)
print("Validation batches:", validation_steps)
# Out:
# WARNING:tensorflow:From <ipython-input-6-f5ec5bd77260>:13: HDF5Matrix.__init__ (from tensorflow.python.keras.utils.io_utils) is deprecated and will be removed after 2020-05-30.
# Instructions for updating:
# Training with HDF5Matrix is not optimized for performance. Instead, we recommend using https://github.com/tensorflow/io to load your HDF5 data into a tf.data Dataset and passing that dataset to Keras.
# /home/claudio/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/utils/io_utils.py:133: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   f = h5py.File(datapath)
# Validation batches: 2275

# %%
## Un-comment this code if you want to reload the data from the .hdf5 file for some reason
#import pickle
#X,y = load_inputs_31(target_list, shuffle=False)
#pickle.dump((X,y), open("dataset_sseq_singleseq.pic",'wb'))

# %%
import pickle
(X,y) = pickle.load(open("data/dataset_sseq_singleseq.pic",'rb'))

# %%
batch=32

hist = model_sseq.fit(generate_inputs_window_31(X,y,train_list, batch), 
               validation_data=generate_inputs_window_31(X,y,validation_list, batch), 
               epochs=30, steps_per_epoch=1000, validation_steps=validation_steps, batch_size=batch)
# Out:
# Epoch 1/30
# 1000/1000 [==============================] - 35s 35ms/step - loss: 1.0025 - sparse_categorical_accuracy: 0.4915 - val_loss: 0.9551 - val_sparse_categorical_accuracy: 0.5378
# Epoch 2/30
# 1000/1000 [==============================] - 35s 35ms/step - loss: 0.9289 - sparse_categorical_accuracy: 0.5545 - val_loss: 0.9499 - val_sparse_categorical_accuracy: 0.5389
# Epoch 3/30
# 1000/1000 [==============================] - 30s 30ms/step - loss: 0.9193 - sparse_categorical_accuracy: 0.5615 - val_loss: 0.9968 - val_sparse_categorical_accuracy: 0.5532
# Epoch 4/30
# 1000/1000 [==============================] - 32s 32ms/step - loss: 0.8781 - sparse_categorical_accuracy: 0.5928 - val_loss: 0.8906 - val_sparse_categorical_accuracy: 0.5871
# Epoch 5/30
# 1000/1000 [==============================] - 30s 30ms/step - loss: 0.8662 - sparse_categorical_accuracy: 0.6032 - val_loss: 0.8968 - val_sparse_categorical_accuracy: 0.5862
# Epoch 6/30
# 1000/1000 [==============================] - 34s 34ms/step - loss: 0.8649 - sparse_categorical_accuracy: 0.6049 - val_loss: 0.8468 - val_sparse_categorical_accuracy: 0.6210
# Epoch 7/30
# 1000/1000 [==============================] - 37s 37ms/step - loss: 0.8244 - sparse_categorical_accuracy: 0.6343 - val_loss: 0.9007 - val_sparse_categorical_accuracy: 0.6033
# Epoch 8/30
# 1000/1000 [==============================] - 41s 41ms/step - loss: 0.8336 - sparse_categorical_accuracy: 0.6286 - val_loss: 0.8410 - val_sparse_categorical_accuracy: 0.6240
# Epoch 9/30
# 1000/1000 [==============================] - 39s 39ms/step - loss: 0.8070 - sparse_categorical_accuracy: 0.6433 - val_loss: 0.8306 - val_sparse_categorical_accuracy: 0.6301
# Epoch 10/30
# 1000/1000 [==============================] - 41s 41ms/step - loss: 0.8245 - sparse_categorical_accuracy: 0.6326 - val_loss: 0.8117 - val_sparse_categorical_accuracy: 0.6420
# Epoch 11/30
# 1000/1000 [==============================] - 40s 40ms/step - loss: 0.8133 - sparse_categorical_accuracy: 0.6413 - val_loss: 0.8364 - val_sparse_categorical_accuracy: 0.6385
# Epoch 12/30
# 1000/1000 [==============================] - 34s 34ms/step - loss: 0.8045 - sparse_categorical_accuracy: 0.6473 - val_loss: 0.8319 - val_sparse_categorical_accuracy: 0.6325
# Epoch 13/30
#  700/1000 [====================>.........] - ETA: 6s - loss: 0.8094 - sparse_categorical_accuracy: 0.6389

# %%
plot_loss_acc(hist)

# %% [markdown]
# * What is the best validation performance that you can extract from your Model?
# * What would be the best naïve classifier for this dataset? How does the validation performance of your model compare to it?
# * What do you think of randomly splitting the dataset this way? Can you think of a better way of doing it? Can you think of a _worse_ day of doing it?

# %%
distance_matrix = pd.read_csv('data/trainset_distance_matrix.tsv', sep='\t')
dists = squareform(distance_matrix)
linkage_matrix = linkage(dists, "single")
dendrogram(linkage_matrix)
plt.show()

# %%
cluster_assignments = fcluster(linkage_matrix,criterion='distance', t=0.7)
print(len(cluster_assignments), np.max(cluster_assignments))

target_list_file = open(target_list_path)
target_list = target_list_file.readlines()

train_list_cluster = []
validation_list_cluster = []
validation_size_limit = int(n_targets/20)

for i in range(1,np.max(cluster_assignments)+1):
    index_this_cluster = np.where(cluster_assignments == i)[0]
    if len(validation_list_cluster) < validation_size_limit:
        validation_list_cluster += [target_list[element] for element in index_this_cluster]
    else:
        train_list_cluster += [target_list[element] for element in index_this_cluster]
# Out:
# 6546 5363
# 403 6143 327

# %%
random.shuffle(train_list_cluster)
validation_steps_cluster = count_steps_31(validation_list_cluster, batch)
print("Validation batches:", validation_steps_cluster)

hist2 = model_sseq.fit(generate_inputs_window_31(X,y,train_list_cluster, batch), 
               validation_data=generate_inputs_window_31(X,y,validation_list_cluster, batch), 
               epochs=30, steps_per_epoch=1000, validation_steps=validation_steps_cluster, batch_size=batch)
# Out:
# Validation batches: 3795
# Epoch 1/30
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.7312 - sparse_categorical_accuracy: 0.6915 - val_loss: 0.7361 - val_sparse_categorical_accuracy: 0.6872
# Epoch 2/30
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.7219 - sparse_categorical_accuracy: 0.6932 - val_loss: 0.8426 - val_sparse_categorical_accuracy: 0.6289
# Epoch 3/30
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.7149 - sparse_categorical_accuracy: 0.6972 - val_loss: 0.7234 - val_sparse_categorical_accuracy: 0.6953
# Epoch 4/30
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.7232 - sparse_categorical_accuracy: 0.6946 - val_loss: 0.7691 - val_sparse_categorical_accuracy: 0.6803
# Epoch 5/30
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.7074 - sparse_categorical_accuracy: 0.7047 - val_loss: 0.7371 - val_sparse_categorical_accuracy: 0.6898
# Epoch 6/30
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.7131 - sparse_categorical_accuracy: 0.7031 - val_loss: 0.7603 - val_sparse_categorical_accuracy: 0.6849
# Epoch 7/30
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.7143 - sparse_categorical_accuracy: 0.6930 - val_loss: 0.7362 - val_sparse_categorical_accuracy: 0.6858
# Epoch 8/30
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.7207 - sparse_categorical_accuracy: 0.6912 - val_loss: 0.7419 - val_sparse_categorical_accuracy: 0.6876
# Epoch 9/30
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.7102 - sparse_categorical_accuracy: 0.7007 - val_loss: 0.7388 - val_sparse_categorical_accuracy: 0.6890
# Epoch 10/30
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.7391 - sparse_categorical_accuracy: 0.6890 - val_loss: 0.7284 - val_sparse_categorical_accuracy: 0.6889
# Epoch 11/30
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.7370 - sparse_categorical_accuracy: 0.6891 - val_loss: 0.7739 - val_sparse_categorical_accuracy: 0.6613
# Epoch 12/30
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.7149 - sparse_categorical_accuracy: 0.7006 - val_loss: 0.7532 - val_sparse_categorical_accuracy: 0.6820
# Epoch 13/30
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.7310 - sparse_categorical_accuracy: 0.6875 - val_loss: 0.8086 - val_sparse_categorical_accuracy: 0.6730
# Epoch 14/30
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.7168 - sparse_categorical_accuracy: 0.6968 - val_loss: 0.7508 - val_sparse_categorical_accuracy: 0.6831
# Epoch 15/30
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.7361 - sparse_categorical_accuracy: 0.6884 - val_loss: 0.7665 - val_sparse_categorical_accuracy: 0.6699
# Epoch 16/30
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.7344 - sparse_categorical_accuracy: 0.6931 - val_loss: 0.7172 - val_sparse_categorical_accuracy: 0.6926
# Epoch 17/30
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.7157 - sparse_categorical_accuracy: 0.7023 - val_loss: 0.7537 - val_sparse_categorical_accuracy: 0.6801
# Epoch 18/30
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.7151 - sparse_categorical_accuracy: 0.6967 - val_loss: 0.7379 - val_sparse_categorical_accuracy: 0.6881
# Epoch 19/30
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.7135 - sparse_categorical_accuracy: 0.6980 - val_loss: 0.8036 - val_sparse_categorical_accuracy: 0.6824
# Epoch 20/30
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.6999 - sparse_categorical_accuracy: 0.7034 - val_loss: 0.7818 - val_sparse_categorical_accuracy: 0.6615
# Epoch 21/30
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.7115 - sparse_categorical_accuracy: 0.6976 - val_loss: 0.8373 - val_sparse_categorical_accuracy: 0.6890
# Epoch 22/30
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.7178 - sparse_categorical_accuracy: 0.6937 - val_loss: 0.7473 - val_sparse_categorical_accuracy: 0.6790
# Epoch 23/30
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.7190 - sparse_categorical_accuracy: 0.7003 - val_loss: 0.7324 - val_sparse_categorical_accuracy: 0.6900
# Epoch 24/30
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.7206 - sparse_categorical_accuracy: 0.6932 - val_loss: 0.7425 - val_sparse_categorical_accuracy: 0.6841
# Epoch 25/30
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.7395 - sparse_categorical_accuracy: 0.6875 - val_loss: 0.8224 - val_sparse_categorical_accuracy: 0.6278
# Epoch 26/30
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.7380 - sparse_categorical_accuracy: 0.6878 - val_loss: 0.7444 - val_sparse_categorical_accuracy: 0.6938
# Epoch 27/30
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.6990 - sparse_categorical_accuracy: 0.7109 - val_loss: 0.8012 - val_sparse_categorical_accuracy: 0.6864
# Epoch 28/30
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.6991 - sparse_categorical_accuracy: 0.7012 - val_loss: 0.7493 - val_sparse_categorical_accuracy: 0.6894
# Epoch 29/30
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.7275 - sparse_categorical_accuracy: 0.6968 - val_loss: 0.7525 - val_sparse_categorical_accuracy: 0.6895
# Epoch 30/30
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.7172 - sparse_categorical_accuracy: 0.7021 - val_loss: 0.8061 - val_sparse_categorical_accuracy: 0.6762

# %%
plot_loss_acc(hist)
plot_loss_acc(hist2)
